# %%
import imageio.v3 as iio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
MAT_RGB2YIQ = np.array([[0.299, 0.587, 0.114],
                        [0.596,-0.275,-0.321],
                        [0.211,-0.523, 0.311]])

def apply_matrix(img, M):
    return np.matmul( img.reshape((-1,3)), M.T ).reshape(img.shape)

# %%
img_rgb = iio.imread('imageio:astronaut.png') / 255
plt.imshow(img_rgb)

img_YIQ = apply_matrix(img_rgb, MAT_RGB2YIQ)
canal_Y = img_YIQ[:,:,0]

plt.imshow(canal_Y, 'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-712c9745ba99> in <cell line: 1>()
# ----> 1 img_rgb = iio.imread('imageio:astronaut.png') / 255
#       2 plt.imshow(img_rgb)
#       3
#       4 img_YIQ = apply_matrix(img_rgb, MAT_RGB2YIQ)
#       5 canal_Y = img_YIQ[:,:,0]
#
# NameError: name 'iio' is not defined

# %%
# Out:
# 9
