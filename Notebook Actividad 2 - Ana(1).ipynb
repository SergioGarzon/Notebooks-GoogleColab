# %%
import pandas as pd

#import os
# os.chdir("C:/Usuarios/Ana/Escritorio/Proyecto_Actividad_2")

# %%
poblacion_df = pd.read_csv('poblacion.csv', encoding='latin-1')

# %%
print('La cantidad de filas y de columnas de poblacion son: ')
poblacion_df.shape
# Out:
# La cantidad de filas y de columnas de poblacion son:
# (775, 5)

# %%
poblacion_df
# Out:
#             provincia  anio  poblacion_total  poblacion_varones  \
# 0          Total País  2010         40788453           19940704
# 1          Total País  2011         41261490           20180791
# 2          Total País  2012         41733271           20420391
# 3          Total País  2013         42202935           20659037
# 4          Total País  2014         42669500           20896203
# ..                ...   ...              ...                ...
# 770  Tierra del Fuego  2036           241593             122567
# 771  Tierra del Fuego  2037           245734             124625
# 772  Tierra del Fuego  2038           249853             126670
# 773  Tierra del Fuego  2039           253948             128702
# 774  Tierra del Fuego  2040           258020             130721
#
#      poblacion_mujeres
# 0             20847749
# 1             21080699
# 2             21312880
# 3             21543898
# 4             21773297
# ..                 ...
# 770             119026
# ...

# %%
empleo_df = pd.read_csv('empleo.csv', encoding='latin-1')

# %%
print('La cantidad de filas y de columnas de empleo son: ')
empleo_df.shape
# Out:
# La cantidad de filas y de columnas de empleo son:
# (3696, 4)

# %%
empleo_df
# Out:
#          provincia  anio     mes  empleados_registrados_miles
# 0     Buenos Aires  2009  ene-09                     1787.640
# 1     Buenos Aires  2009  feb-09                     1769.223
# 2     Buenos Aires  2009  mar-09                     1745.913
# 3     Buenos Aires  2009  abr-09                     1729.917
# 4     Buenos Aires  2009  may-09                     1723.218
# ...            ...   ...     ...                          ...
# 3691       Tucumán  2021  jun-21                      172.053
# 3692       Tucumán  2021  jul-21                      172.030
# 3693       Tucumán  2021  ago-21                      171.015
# 3694       Tucumán  2021  sep-21                      168.084
# 3695       Tucumán  2021  oct-21                      165.578
#
# [3696 rows x 4 columns]

# %%
esperanza_de_vida_df = pd.read_csv('esperanza_de_vida.csv', encoding='latin-1')

# %%
print('La cantidad de filas y columnas de esperanza de vida son: ')
esperanza_de_vida_df.shape
# Out:
# La cantidad de filas y columnas de esperanza de vida son:
# (144, 4)

# %%
esperanza_de_vida_df
# Out:
#         provincia  anio  mujeres  varones
# 0    Buenos Aires  2015    80.22    73.54
# 1    Buenos Aires  2020    81.34    74.74
# 2    Buenos Aires  2025    82.32    75.80
# 3    Buenos Aires  2030    83.20    76.76
# 4    Buenos Aires  2035    83.98    77.60
# ..            ...   ...      ...      ...
# 139       Tucumán  2020    81.05    75.11
# 140       Tucumán  2025    82.11    76.15
# 141       Tucumán  2030    83.03    77.07
# 142       Tucumán  2035    83.84    77.88
# 143       Tucumán  2040    84.54    78.58
#
# [144 rows x 4 columns]

# %%
exportaciones_df = pd.read_csv('exportaciones.csv', encoding='latin-1')

# %%
print('La cantidad de filas y columnas de exportaciones son: ')
exportaciones_df.shape
# Out:
# La cantidad de filas y columnas de exportaciones son:
# (2000, 4)

# %%
exportaciones_df
# Out:
#                        rubro        provincia  anio      value
# 0                      Total       Total País  2005  40386.762
# 1                      Total     Buenos Aires  2005  15626.865
# 2                      Total  Capital Federal  2005    271.295
# 3                      Total          Córdoba  2005   4452.178
# 4                      Total       Entre Ríos  2005    815.341
# ...                      ...              ...   ...        ...
# 1995  Combustibles y energía         San Luis  2020          0
# 1996  Combustibles y energía            Chaco  2020          0
# 1997  Combustibles y energía       Corrientes  2020    373.938
# 1998  Combustibles y energía          Formosa  2020      5.169
# 1999  Combustibles y energía         Misiones  2020          0
#
# [2000 rows x 4 columns]

# %%
hogares_viviendas_superficie_df = pd.read_csv('hogares_viviendas_superficie.csv', encoding = 'latin-1')

# %%
print('La cantidad de filas y columnas de hogares viviendas superficies son: ')
hogares_viviendas_superficie_df.shape
# Out:
# La cantidad de filas y columnas de hogares viviendas superficies son:
# (24, 6)

# %%
hogares_viviendas_superficie_df
# Out:
#     provincia_id            provincia  hogares  viviendas_particulares  \
# 0              2      Capital Federal  1150134                 1423973
# 1              6         Buenos Aires  4789484                 5377786
# 2             10            Catamarca    96001                  113634
# 3             14              Córdoba  1031843                 1232211
# 4             18           Corrientes   267797                  292644
# 5             22                Chaco   288422                  312602
# 6             26               Chubut   157166                  177985
# 7             30           Entre Ríos   375121                  425591
# 8             34              Formosa   140303                  154458
# 9             38                Jujuy   174630                  195785
# 10            42             La Pampa   107674                  133186
# 11            46             La Rioja    91097                  108967
# ...

# %%
# Chequeos basicos de los dataframes

# %%
# Cambiamos el tipo de dato de la columna provincia

# Segun vi, no es necesario cambiar ningun tipo de dato, ya que parece que estan todos correctos.
# poblacion_df = poblacion_df.astype({"provincia": str, "anio": int})

# %%
print('Verificar los tipos de datos de poblacion: ')
poblacion_df.dtypes
# Out:
# Verificar los tipos de datos de poblacion:
# provincia            object
# anio                  int64
# poblacion_total       int64
# poblacion_varones     int64
# poblacion_mujeres     int64
# dtype: object

# %%
print('Verificar los tipos de datos de empleos: ')
empleo_df.dtypes
# Out:
# Verificar los tipos de datos de empleos:
# provincia                       object
# anio                             int64
# mes                             object
# empleados_registrados_miles    float64
# dtype: object

# %%
print('Verificar los tipos de datos de experanza de vida: ')
esperanza_de_vida_df.dtypes
# Out:
# Verificar los tipos de datos de experanza de vida:
# provincia     object
# anio           int64
# mujeres      float64
# varones      float64
# dtype: object

# %%
print('Verificar los tipos de datos de experanza de vida: ')
exportaciones_df.dtypes
# Out:
# Verificar los tipos de datos de experanza de vida:
# rubro        object
# provincia    object
# anio          int64
# value        object
# dtype: object

# %%
print('Verificar los tipos de datos de hogares, viviendas y superficies: ')
hogares_viviendas_superficie_df.dtypes
# Out:
# Verificar los tipos de datos de hogares, viviendas y superficies:
# provincia_id                         int64
# provincia                           object
# hogares                              int64
# viviendas_particulares               int64
# viviendas_particulares_habitadas     int64
# superficie_km2                       int64
# dtype: object

# %%
poblacion_df.head()
# Out:
#     provincia  anio  poblacion_total  poblacion_varones  poblacion_mujeres
# 0  Total País  2010         40788453           19940704           20847749
# 1  Total País  2011         41261490           20180791           21080699
# 2  Total País  2012         41733271           20420391           21312880
# 3  Total País  2013         42202935           20659037           21543898
# 4  Total País  2014         42669500           20896203           21773297

# %%
# Estadisticas descriptivas

# %%
print('Estadistica descriptiva de población: ')
poblacion_df.describe()
# Out:
# Estadistica descriptiva de población:
#               anio  poblacion_total  poblacion_varones  poblacion_mujeres
# count   775.000000     7.750000e+02       7.750000e+02       7.750000e+02
# mean   2025.000000     3.777746e+06       1.856888e+06       1.920858e+06
# std       8.950048     9.560571e+06       4.699604e+06       4.861043e+06
# min    2010.000000     1.316610e+05       6.723500e+04       6.442600e+04
# 25%    2017.000000     5.845510e+05       2.906740e+05       2.934905e+05
# 50%    2025.000000     1.017731e+06       5.061010e+05       5.161370e+05
# 75%    2033.000000     1.855285e+06       9.138865e+05       9.404745e+05
# max    2040.000000     5.277848e+07       2.603809e+07       2.674038e+07

# %%
# Para ver tipos de datos y tamaño del dataframe poblacion, utilizo la funcion info()

poblacion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   provincia          775 non-null    object
#  1   anio               775 non-null    int64
#  2   poblacion_total    775 non-null    int64
#  3   poblacion_varones  775 non-null    int64
#  4   poblacion_mujeres  775 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 30.4+ KB

# %%
# Chequeos basicos de empleo

empleo_df.head()
empleo_df.describe()
empleo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   provincia                    3696 non-null   object
#  1   anio                         3696 non-null   int64
#  2   mes                          3696 non-null   object
#  3   empleados_registrados_miles  3696 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 115.6+ KB

# %%
# Chequeos basicos de esperanza de vida

esperanza_de_vida_df.head()
esperanza_de_vida_df.describe()
esperanza_de_vida_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   provincia  144 non-null    object
#  1   anio       144 non-null    int64
#  2   mujeres    144 non-null    float64
#  3   varones    144 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.6+ KB

# %%
# Chequeo del dataframe de exportaciones

exportaciones_df.head()
exportaciones_df.describe()
exportaciones_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rubro      2000 non-null   object
#  1   provincia  2000 non-null   object
#  2   anio       2000 non-null   int64
#  3   value      2000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 62.6+ KB

# %%
# Chequeos basicos del dataframe de hogares viviendas superficie

hogares_viviendas_superficie_df.head()
hogares_viviendas_superficie_df.describe()
hogares_viviendas_superficie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   provincia_id                      24 non-null     int64
#  1   provincia                         24 non-null     object
#  2   hogares                           24 non-null     int64
#  3   viviendas_particulares            24 non-null     int64
#  4   viviendas_particulares_habitadas  24 non-null     int64
#  5   superficie_km2                    24 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
# Punto Numero 2

# Calculá un campo nuevo, densidad (población/superficie) y usar la función descrita sobre ese campo nuevo.

merge_df = pd.merge(poblacion_df, hogares_viviendas_superficie_df, on='provincia', how='inner')

# %%
merge_df['densidad_poblacion'] = merge_df['poblacion_total'] / merge_df['superficie_km2']

# %%
merge_df['densidad_poblacion']
# Out:
# 0      15142.405000
# 1      15168.195000
# 2      15194.300000
# 3      15220.380000
# 4      15246.145000
#            ...
# 739        0.241004
# 740        0.245135
# 741        0.249244
# 742        0.253329
# 743        0.257391
# Name: densidad_poblacion, Length: 744, dtype: float64

# %%
merge_df
# Out:
#             provincia  anio  poblacion_total  poblacion_varones  \
# 0     Capital Federal  2010          3028481            1405566
# 1     Capital Federal  2011          3033639            1409835
# 2     Capital Federal  2012          3038860            1414105
# 3     Capital Federal  2013          3044076            1418339
# 4     Capital Federal  2014          3049229            1422507
# ..                ...   ...              ...                ...
# 739  Tierra del Fuego  2036           241593             122567
# 740  Tierra del Fuego  2037           245734             124625
# 741  Tierra del Fuego  2038           249853             126670
# 742  Tierra del Fuego  2039           253948             128702
# 743  Tierra del Fuego  2040           258020             130721
#
#      poblacion_mujeres  provincia_id  hogares  viviendas_particulares  \
# 0              1622915             2  1150134                 1423973
# ...

# %%
merge_df.head()
# Out:
#          provincia  anio  poblacion_total  poblacion_varones  \
# 0  Capital Federal  2010          3028481            1405566
# 1  Capital Federal  2011          3033639            1409835
# 2  Capital Federal  2012          3038860            1414105
# 3  Capital Federal  2013          3044076            1418339
# 4  Capital Federal  2014          3049229            1422507
#
#    poblacion_mujeres  provincia_id  hogares  viviendas_particulares  \
# 0            1622915             2  1150134                 1423973
# 1            1623804             2  1150134                 1423973
# 2            1624755             2  1150134                 1423973
# 3            1625737             2  1150134                 1423973
# 4            1626722             2  1150134                 1423973
#
#    viviendas_particulares_habitadas  superficie_km2  densidad_poblacion
# 0                           1082998             200           15142.405
# ...

# %%
# Identificá si existe algún valor extremo en la densidad de población y explicó a qué podría deberse esto.

# Este punto no lo entendi mucho que digamos, estuve viendo en internet como hacerlo, espero que les sirva.

# %%
merge_df['densidad_poblacion']
# Out:
# 0      15142.405000
# 1      15168.195000
# 2      15194.300000
# 3      15220.380000
# 4      15246.145000
#            ...
# 739        0.241004
# 740        0.245135
# 741        0.249244
# 742        0.253329
# 743        0.257391
# Name: densidad_poblacion, Length: 744, dtype: float64

# %%
mean = merge_df['densidad_poblacion'].mean()

# %%
std_dev = merge_df['densidad_poblacion'].std()

# %%
limite_bajo = mean - 2 * std_dev

# %%
limite_superior = mean + 2 * std_dev

# %%
outliers = merge_df[(merge_df['densidad_poblacion'] < lower_limit) | (merge_df['densidad_poblacion'] > upper_limit)]

# %%
print(outliers)
# Out:
#           provincia  anio  poblacion_total  poblacion_varones  \
# 0   Capital Federal  2010          3028481            1405566
# 1   Capital Federal  2011          3033639            1409835
# 2   Capital Federal  2012          3038860            1414105
# 3   Capital Federal  2013          3044076            1418339
# 4   Capital Federal  2014          3049229            1422507
# 5   Capital Federal  2015          3054267            1426582
# 6   Capital Federal  2016          3059122            1430531
# 7   Capital Federal  2017          3063728            1434323
# 8   Capital Federal  2018          3068043            1437936
# 9   Capital Federal  2019          3072029            1441350
# 10  Capital Federal  2020          3075646            1444545
# 11  Capital Federal  2021          3078836            1447495
# 12  Capital Federal  2022          3081550            1450179
# 13  Capital Federal  2023          3083770            1452588
# ...

# %%
print('He notado que hay una alta densidad de población en algunos lugares como ser Capital Federal debido a la concentración de personas en espacios reducidos')
# Out:
# He notado que hay una alta densidad de población en algunos lugares como ser Capital Federal debido a la concentración de personas en espacios reducidos
