# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2023**
#
# ---
# ## Trabajo práctico entregable - Parte 1

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
url = 'https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/master/sysarmy_survey_2022_processed.csv'
df = pd.read_csv(url)

# %%
df[:19]
# Out:
#    work_country work_province work_dedication  \
# 0     Argentina     Catamarca       Full-Time
# 1     Argentina         Chaco       Full-Time
# 2     Argentina         Chaco       Full-Time
# 3     Argentina         Chaco       Full-Time
# 4     Argentina         Chaco       Full-Time
# 5     Argentina         Chaco       Full-Time
# 6     Argentina         Chaco       Full-Time
# 7     Argentina         Chaco       Full-Time
# 8     Argentina         Chaco       Part-Time
# 9     Argentina         Chaco       Full-Time
# 10    Argentina         Chaco       Full-Time
# 11    Argentina         Chaco       Full-Time
# 12    Argentina         Chaco       Full-Time
# 13    Argentina         Chaco       Full-Time
# 14    Argentina         Chaco       Full-Time
# 15    Argentina         Chaco       Full-Time
# 16    Argentina         Chaco       Full-Time
# 17    Argentina         Chaco       Full-Time
# 18    Argentina         Chaco       Part-Time
#
#                                    work_contract_type  salary_monthly_BRUTO  \
# 0                           Staff (planta permanente)              300000.0
# 1                       Remoto (empresa de otro país)              900000.0
# 2                           Staff (planta permanente)              120000.0
# 3                       Remoto (empresa de otro país)              440000.0
# 4                           Staff (planta permanente)              140000.0
# 5                           Staff (planta permanente)              633000.0
# 6                           Staff (planta permanente)              110000.0
# 7                           Staff (planta permanente)              157000.0
# 8                           Staff (planta permanente)               55000.0
# 9                       Remoto (empresa de otro país)              190000.0
# 10                          Staff (planta permanente)              242000.0
# 11                          Staff (planta permanente)              280000.0
# 12                          Staff (planta permanente)              329850.0
# 13                      Remoto (empresa de otro país)              625000.0
# 14                          Staff (planta permanente)              222500.0
# 15                          Staff (planta permanente)              380000.0
# 16                          Staff (planta permanente)              156000.0
# 17  Tercerizado (trabajo a través de consultora o ...              200000.0
# 18  Tercerizado (trabajo a través de consultora o ...               50000.0
#
#     salary_monthly_NETO  numero  \
# 0              245000.0    True
# 1              850000.0    True
# 2              115000.0    True
# 3                   0.0    True
# 4              125000.0    True
# 5              395000.0    True
# 6               90000.0    True
# 7              127000.0    True
# 8               45650.0    True
# 9              178000.0    True
# 10             202029.0    True
# 11             180000.0    True
# 12             315000.0    True
# 13             625000.0    True
# 14             180700.0    True
# 15             317000.0    True
# 16             150000.0    True
# 17             176000.0    True
# 18              45000.0    True
#
#                                         salary_in_usd  \
# 0                                                 NaN
# 1                    Cobro todo el salario en dólares
# 2                                                 NaN
# 3                    Cobro todo el salario en dólares
# 4                                                 NaN
# 5                  Cobro parte del salario en dólares
# 6   Mi sueldo está dolarizado (pero cobro en moned...
# 7                                                 NaN
# 8                                                 NaN
# 9                    Cobro todo el salario en dólares
# 10  Mi sueldo está dolarizado (pero cobro en moned...
# 11                                                NaN
# 12                 Cobro parte del salario en dólares
# 13                   Cobro todo el salario en dólares
# 14                                                NaN
# 15                   Cobro todo el salario en dólares
# 16                                                NaN
# 17                                                NaN
# 18  Mi sueldo está dolarizado (pero cobro en moned...
#
#    salary_last_dollar_value                    salary_pay_cripto  ...  \
# 0                       NaN                                  NaN  ...
# 1                       300                                  NaN  ...
# 2                       NaN                                  NaN  ...
# 3                       220  Cobro todo el salario criptomonedas  ...
# 4                       NaN                                  NaN  ...
# 5                       NaN                                  NaN  ...
# 6                       125                                  NaN  ...
# 7                       NaN                                  NaN  ...
# 8                       NaN                                  NaN  ...
# 9                       NaN                                  NaN  ...
# 10                      132                                  NaN  ...
# 11                      NaN                                  NaN  ...
# 12                      NaN                                  NaN  ...
# 13                      250                                  NaN  ...
# 14                      NaN                                  NaN  ...
# 15                      NaN                                  NaN  ...
# 16                      NaN                                  NaN  ...
# 17                      NaN                                  NaN  ...
# 18                      250                                  NaN  ...
#
#    profile_studies_level_state                                 profile_career  \
# 0                     Completo  Licenciatura en redes y comunicación de datos
# 1                          NaN                                            NaN
# 2                          NaN                                            NaN
# 3                          NaN                                            NaN
# 4                          NaN                                            NaN
# 5                     Completo        Licenciatura en Sistemas de Información
# 6                   Incompleto                    Tecnicatura en Programación
# 7                     Completo                 Licenciatura en Administración
# 8                     En curso          Ingeniería en Sistemas de Información
# 9                   Incompleto          Ingeniería en Sistemas de Información
# 10                    En curso                                Electromecánica
# 11                    Completo          Ingeniería en Sistemas de Información
# 12                    Completo          Ingeniería en Sistemas de Información
# 13                    En curso          Ingeniería en Sistemas de Información
# 14                    En curso                     ingeniería electromecánica
# 15                    En curso          Ingeniería en Sistemas de Información
# 16                    En curso           Tecnicatura Superior en Programación
# 17                         NaN                                            NaN
# 18                         NaN                                            NaN
#
#                           profile_university  \
# 0                UP - Universidad de Palermo
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5   UNNE - Universidad Nacional Del Nordeste
# 6                     Instituto Barranqueras
# 7   UCP - Universidad de la Cuenca del Plata
# 8                                     UNCAus
# 9                                        NaN
# 10    UTN - Universidad Tecnológica Nacional
# 11    UTN - Universidad Tecnológica Nacional
# 12    UTN - Universidad Tecnológica Nacional
# 13    UTN - Universidad Tecnológica Nacional
# 14    UTN - Universidad Tecnológica Nacional
# 15    UTN - Universidad Tecnológica Nacional
# 16    UTN - Universidad Tecnológica Nacional
# 17                                       NaN
# 18                                       NaN
#
#                            profile_boot_camp profile_boot_camp_carrer  \
# 0                                        NaN                      NaN
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                      NaN
# 5                                        NaN                      NaN
# 6                         Informatorio Chaco         Programación web
# 7                                        NaN                      NaN
# 8                                    crowdar               Qa Analyst
# 9                                        NaN                      NaN
# 10                                       NaN             Informatorio
# 11                                        No                      NaN
# 12                                       NaN                      NaN
# 13                                       NaN                      NaN
# 14  informatorio, codo a codo, digital house             Java backend
# 15                                       NaN                      NaN
# 16                                       NaN                      NaN
# 17                                       NaN                      NaN
# 18                                       NaN                      NaN
#
#    work_on_call_duty  salary_on_call_duty_charge  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
# 5                NaN                         NaN
# 6                 No                         0.0
# 7                 No                         0.0
# 8                NaN                         NaN
# 9                NaN                         NaN
# 10                No                         0.0
# 11               NaN                         NaN
# 12                No                         0.0
# 13               NaN                         NaN
# 14                No                         0.0
# 15               NaN                         NaN
# 16               NaN                         NaN
# 17               NaN                         NaN
# 18               NaN                         NaN
#
#     work_on_call_duty_charge_type  profile_age profile_gender
# 0                             NaN           35      Varón Cis
# 1                             NaN           31      Varón Cis
# 2                             NaN           27      Varón Cis
# 3                             NaN           21      Varón Cis
# 4                             NaN           32      Varón Cis
# 5                             NaN           31      Varón Cis
# 6   Porcentaje de mi sueldo bruto           33      Varón Cis
# 7                           Bruto           35      Varón Cis
# 8                             NaN           28      Varón Cis
# 9                             NaN           29      Varón Cis
# 10  Porcentaje de mi sueldo bruto           30      Varón Cis
# 11                            NaN           56      Varón Cis
# 12  Porcentaje de mi sueldo bruto           45      Varón Cis
# 13                            NaN           23      Varón Cis
# 14  Porcentaje de mi sueldo bruto           25      Varón Cis
# 15                            NaN           29      Varón Cis
# 16                            NaN           29      Varón Cis
# 17                            NaN           33      Varón Cis
# 18                            NaN           43      Varón Cis
#
# [19 rows x 44 columns]

# %% [markdown]
# Columnas seleccionadas:
# work_dedication
# work_contract_type
# max(salary_monthly_BRUTO, salary_monthly_NETO)

# %% [markdown]
# # Ejercicio 1 - Análisis descriptivo
#
# Responder a la pregunta: **¿Cuáles son los lenguajes de programación asociados a los mejores salarios?**
#
# Para ello:
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en una sub-población. Por ejemplo, se pueden limitar a personas con un salario mayor que 10000 pesos, o a las personas que trabajan sólo en "Data Science", pero deben justificar su elección y reformular la pregunta inicial de ser necesario.
#   * Obtener una lista de los lenguajes de programación más populares. Decidir cuántos y cuáles seleccionan para incluir en el análisis.
#   * Para cada una de las otras columnas del punto anterior, elegir los rangos o valores seleccionan para incluir en el análisis.
# 3. Seleccionar métricas que ayuden a responder la pregunta, y los métodos para analizarlas. Elegir UNA de las siguientes opciones:
#   * Comparar las distribuciones de salario para cada lenguaje utilizando visualizaciones. Como la visualización es el producto final, debe ser clara y mostrar información relevante.
#   * Comparar medidas de estadística descriptiva sobre la distribución de salario para cada lenguaje. Sean creativos, la estadística descriptiva nos permite decir cosas como: "el 10% de los mejores sueldos los ganan, en su mayoría, programadores que saben kotlin!" (donde *mayoría* es un término medio engañoso que sólo significa más del 50%). Para comparar múltiples lenguajes, les recomendamos usar también visualizaciones.
#   * Comparar probabilidades. Por ejemplo: "Si sabés Python o Java, tenés un 30% más de chances de ganar arriba de 100K".
#
# Si lo consideran necesario, realicen varias iteraciones. Es decir, si encuentran que las distribuciones de los lenguajes de programación que seleccionaron inicialmente no son muy diferentes, pueden re-hacer el análisis usando sólo los lenguajes de programación que son diferentes.

# %%
df["sueldo_verdad"] =df[["salary_monthly_NETO", "salary_monthly_BRUTO"]].max(axis=1)

# %%
df
# Out:
#      work_country work_province work_dedication  \
# 0       Argentina     Catamarca       Full-Time
# 1       Argentina         Chaco       Full-Time
# 2       Argentina         Chaco       Full-Time
# 3       Argentina         Chaco       Full-Time
# 4       Argentina         Chaco       Full-Time
# ...           ...           ...             ...
# 5353    Argentina       Tucumán       Full-Time
# 5354    Argentina       Tucumán       Full-Time
# 5355    Argentina       Tucumán       Full-Time
# 5356    Argentina       Tucumán       Full-Time
# 5357    Argentina       Tucumán       Part-Time
#
#                  work_contract_type  salary_monthly_BRUTO  \
# 0         Staff (planta permanente)              300000.0
# 1     Remoto (empresa de otro país)              900000.0
# 2         Staff (planta permanente)              120000.0
# 3     Remoto (empresa de otro país)              440000.0
# 4         Staff (planta permanente)              140000.0
# ...                             ...                   ...
# 5353      Staff (planta permanente)                 311.7
# 5354      Staff (planta permanente)              150000.0
# 5355  Remoto (empresa de otro país)              230000.0
# 5356      Staff (planta permanente)              450989.0
# 5357                      Freelance               60000.0
#
#       salary_monthly_NETO  numero                       salary_in_usd  \
# 0                245000.0    True                                 NaN
# 1                850000.0    True    Cobro todo el salario en dólares
# 2                115000.0    True                                 NaN
# 3                     0.0    True    Cobro todo el salario en dólares
# 4                125000.0    True                                 NaN
# ...                   ...     ...                                 ...
# 5353                214.8    True  Cobro parte del salario en dólares
# 5354              93000.0    True  Cobro parte del salario en dólares
# 5355             190900.0    True  Cobro parte del salario en dólares
# 5356             297750.0    True  Cobro parte del salario en dólares
# 5357              45000.0    True                                 NaN
#
#      salary_last_dollar_value                    salary_pay_cripto  ...  \
# 0                         NaN                                  NaN  ...
# 1                         300                                  NaN  ...
# 2                         NaN                                  NaN  ...
# 3                         220  Cobro todo el salario criptomonedas  ...
# 4                         NaN                                  NaN  ...
# ...                       ...                                  ...  ...
# 5353                      128                                  NaN  ...
# 5354                   134,89                                  NaN  ...
# 5355                      130                                  NaN  ...
# 5356                   131,55                                  NaN  ...
# 5357                      NaN                                  NaN  ...
#
#                                      profile_career  \
# 0     Licenciatura en redes y comunicación de datos
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5353                                            NaN
# 5354                                            NaN
# 5355                                            NaN
# 5356          Ingeniería en Sistemas de Información
# 5357                           Analista de Sistemas
#
#                           profile_university profile_boot_camp  \
# 0                UP - Universidad de Palermo               NaN
# 1                                        NaN               NaN
# 2                                        NaN               NaN
# 3                                        NaN               NaN
# 4                                        NaN               NaN
# ...                                      ...               ...
# 5353                                     NaN               NaN
# 5354                                     NaN               NaN
# 5355                                     NaN               NaN
# 5356  UTN - Universidad Tecnológica Nacional               NaN
# 5357  UTN - Universidad Tecnológica Nacional            LabsXD
#
#      profile_boot_camp_carrer work_on_call_duty salary_on_call_duty_charge  \
# 0                         NaN               NaN                        NaN
# 1                         NaN               NaN                        NaN
# 2                         NaN               NaN                        NaN
# 3                         NaN               NaN                        NaN
# 4                         NaN               NaN                        NaN
# ...                       ...               ...                        ...
# 5353                      NaN               NaN                        NaN
# 5354                      NaN               NaN                        NaN
# 5355                      NaN               NaN                        NaN
# 5356                      NaN                No                        0.0
# 5357        Quality Assurance                No                        0.0
#
#       work_on_call_duty_charge_type profile_age  profile_gender sueldo_verdad
# 0                               NaN          35       Varón Cis      300000.0
# 1                               NaN          31       Varón Cis      900000.0
# 2                               NaN          27       Varón Cis      120000.0
# 3                               NaN          21       Varón Cis      440000.0
# 4                               NaN          32       Varón Cis      140000.0
# ...                             ...         ...             ...           ...
# 5353                            NaN          40       Mujer Cis         311.7
# 5354                            NaN          33       Mujer Cis      150000.0
# 5355                            NaN          35           Mujer      230000.0
# 5356                           Neto          39       Varón cis      450989.0
# 5357                           Neto          33        Bigénero       60000.0
#
# [5358 rows x 45 columns]

# %%
# complete here if you want to include more columns
relevant_columns = ['work_dedication', 'work_contract_type', 'tools_programming_languages', 'sueldo_verdad']

# %%
#promedio
prom = np.array(df['sueldo_verdad'])
prom = np.mean(prom)


df.sueldo_verdad.mean()
# Out:
# 373891.84703620756

# %%
#mediana
mediana = np.array(df['sueldo_verdad'])
mediana = np.median(mediana)
mediana
# Out:
# 260000.0

# %%
#desviacion estandar
std = np.array(df['sueldo_verdad'])
std = np.std(std)
std
# Out:
# 587436.4676532532

# %%
def clean_outliers_sd(dataset, column_name):
    """Returns dataset removing the outlier rows from column @column_name."""
    interesting_col = dataset[column_name]
    # Here we can remove the outliers from both ends, or even add more restrictions.
    mask_outlier = (
        np.abs(interesting_col - interesting_col.mean()) <=
        (2.5 * interesting_col.std()))
    return dataset[mask_outlier]

# %%
clean_outliers_sd(df,"sueldo_verdad")
# Out:
#      work_country work_province work_dedication  \
# 0       Argentina     Catamarca       Full-Time
# 1       Argentina         Chaco       Full-Time
# 2       Argentina         Chaco       Full-Time
# 3       Argentina         Chaco       Full-Time
# 4       Argentina         Chaco       Full-Time
# ...           ...           ...             ...
# 5353    Argentina       Tucumán       Full-Time
# 5354    Argentina       Tucumán       Full-Time
# 5355    Argentina       Tucumán       Full-Time
# 5356    Argentina       Tucumán       Full-Time
# 5357    Argentina       Tucumán       Part-Time
#
#                  work_contract_type  salary_monthly_BRUTO  \
# 0         Staff (planta permanente)              300000.0
# 1     Remoto (empresa de otro país)              900000.0
# 2         Staff (planta permanente)              120000.0
# 3     Remoto (empresa de otro país)              440000.0
# 4         Staff (planta permanente)              140000.0
# ...                             ...                   ...
# 5353      Staff (planta permanente)                 311.7
# 5354      Staff (planta permanente)              150000.0
# 5355  Remoto (empresa de otro país)              230000.0
# 5356      Staff (planta permanente)              450989.0
# 5357                      Freelance               60000.0
#
#       salary_monthly_NETO  numero                       salary_in_usd  \
# 0                245000.0    True                                 NaN
# 1                850000.0    True    Cobro todo el salario en dólares
# 2                115000.0    True                                 NaN
# 3                     0.0    True    Cobro todo el salario en dólares
# 4                125000.0    True                                 NaN
# ...                   ...     ...                                 ...
# 5353                214.8    True  Cobro parte del salario en dólares
# 5354              93000.0    True  Cobro parte del salario en dólares
# 5355             190900.0    True  Cobro parte del salario en dólares
# 5356             297750.0    True  Cobro parte del salario en dólares
# 5357              45000.0    True                                 NaN
#
#      salary_last_dollar_value                    salary_pay_cripto  ...  \
# 0                         NaN                                  NaN  ...
# 1                         300                                  NaN  ...
# 2                         NaN                                  NaN  ...
# 3                         220  Cobro todo el salario criptomonedas  ...
# 4                         NaN                                  NaN  ...
# ...                       ...                                  ...  ...
# 5353                      128                                  NaN  ...
# 5354                   134,89                                  NaN  ...
# 5355                      130                                  NaN  ...
# 5356                   131,55                                  NaN  ...
# 5357                      NaN                                  NaN  ...
#
#                           profile_university profile_boot_camp  \
# 0                UP - Universidad de Palermo               NaN
# 1                                        NaN               NaN
# 2                                        NaN               NaN
# 3                                        NaN               NaN
# 4                                        NaN               NaN
# ...                                      ...               ...
# 5353                                     NaN               NaN
# 5354                                     NaN               NaN
# 5355                                     NaN               NaN
# 5356  UTN - Universidad Tecnológica Nacional               NaN
# 5357  UTN - Universidad Tecnológica Nacional            LabsXD
#
#      profile_boot_camp_carrer work_on_call_duty salary_on_call_duty_charge  \
# 0                         NaN               NaN                        NaN
# 1                         NaN               NaN                        NaN
# 2                         NaN               NaN                        NaN
# 3                         NaN               NaN                        NaN
# 4                         NaN               NaN                        NaN
# ...                       ...               ...                        ...
# 5353                      NaN               NaN                        NaN
# 5354                      NaN               NaN                        NaN
# 5355                      NaN               NaN                        NaN
# 5356                      NaN                No                        0.0
# 5357        Quality Assurance                No                        0.0
#
#      work_on_call_duty_charge_type  profile_age profile_gender  sueldo_verdad  \
# 0                              NaN           35      Varón Cis       300000.0
# 1                              NaN           31      Varón Cis       900000.0
# 2                              NaN           27      Varón Cis       120000.0
# 3                              NaN           21      Varón Cis       440000.0
# 4                              NaN           32      Varón Cis       140000.0
# ...                            ...          ...            ...            ...
# 5353                           NaN           40      Mujer Cis          311.7
# 5354                           NaN           33      Mujer Cis       150000.0
# 5355                           NaN           35          Mujer       230000.0
# 5356                          Neto           39      Varón cis       450989.0
# 5357                          Neto           33       Bigénero        60000.0
#
#                          cured_programming_languages
# 0                                           [python]
# 1     [css, html, java, javascript, sql, typescript]
# 2                          [javascript, php, python]
# 3                           [javascript, typescript]
# 4                            [css, html, javascript]
# ...                                              ...
# 5353                                              []
# 5354                                              []
# 5355                                     [html, sql]
# 5356                               [javascript, sql]
# 5357                                              []
#
# [5273 rows x 46 columns]

# %%
def clean_outliers_q3(dataset, column_name):
    """Returns dataset removing the outlier rows from column @column_name."""
    interesting_col = dataset[column_name]
    # Here we can remove the outliers from both ends, or even add more restrictions.
    mask_outlier = (interesting_col <= (2.5 * interesting_col.quantile(.75)))
    return dataset[mask_outlier]

# %%
clean_outliers_q3(df,"sueldo_verdad")
# Out:
#      work_country work_province work_dedication  \
# 0       Argentina     Catamarca       Full-Time
# 1       Argentina         Chaco       Full-Time
# 2       Argentina         Chaco       Full-Time
# 3       Argentina         Chaco       Full-Time
# 4       Argentina         Chaco       Full-Time
# ...           ...           ...             ...
# 5353    Argentina       Tucumán       Full-Time
# 5354    Argentina       Tucumán       Full-Time
# 5355    Argentina       Tucumán       Full-Time
# 5356    Argentina       Tucumán       Full-Time
# 5357    Argentina       Tucumán       Part-Time
#
#                  work_contract_type  salary_monthly_BRUTO  \
# 0         Staff (planta permanente)              300000.0
# 1     Remoto (empresa de otro país)              900000.0
# 2         Staff (planta permanente)              120000.0
# 3     Remoto (empresa de otro país)              440000.0
# 4         Staff (planta permanente)              140000.0
# ...                             ...                   ...
# 5353      Staff (planta permanente)                 311.7
# 5354      Staff (planta permanente)              150000.0
# 5355  Remoto (empresa de otro país)              230000.0
# 5356      Staff (planta permanente)              450989.0
# 5357                      Freelance               60000.0
#
#       salary_monthly_NETO  numero                       salary_in_usd  \
# 0                245000.0    True                                 NaN
# 1                850000.0    True    Cobro todo el salario en dólares
# 2                115000.0    True                                 NaN
# 3                     0.0    True    Cobro todo el salario en dólares
# 4                125000.0    True                                 NaN
# ...                   ...     ...                                 ...
# 5353                214.8    True  Cobro parte del salario en dólares
# 5354              93000.0    True  Cobro parte del salario en dólares
# 5355             190900.0    True  Cobro parte del salario en dólares
# 5356             297750.0    True  Cobro parte del salario en dólares
# 5357              45000.0    True                                 NaN
#
#      salary_last_dollar_value                    salary_pay_cripto  ...  \
# 0                         NaN                                  NaN  ...
# 1                         300                                  NaN  ...
# 2                         NaN                                  NaN  ...
# 3                         220  Cobro todo el salario criptomonedas  ...
# 4                         NaN                                  NaN  ...
# ...                       ...                                  ...  ...
# 5353                      128                                  NaN  ...
# 5354                   134,89                                  NaN  ...
# 5355                      130                                  NaN  ...
# 5356                   131,55                                  NaN  ...
# 5357                      NaN                                  NaN  ...
#
#                           profile_university profile_boot_camp  \
# 0                UP - Universidad de Palermo               NaN
# 1                                        NaN               NaN
# 2                                        NaN               NaN
# 3                                        NaN               NaN
# 4                                        NaN               NaN
# ...                                      ...               ...
# 5353                                     NaN               NaN
# 5354                                     NaN               NaN
# 5355                                     NaN               NaN
# 5356  UTN - Universidad Tecnológica Nacional               NaN
# 5357  UTN - Universidad Tecnológica Nacional            LabsXD
#
#      profile_boot_camp_carrer work_on_call_duty salary_on_call_duty_charge  \
# 0                         NaN               NaN                        NaN
# 1                         NaN               NaN                        NaN
# 2                         NaN               NaN                        NaN
# 3                         NaN               NaN                        NaN
# 4                         NaN               NaN                        NaN
# ...                       ...               ...                        ...
# 5353                      NaN               NaN                        NaN
# 5354                      NaN               NaN                        NaN
# 5355                      NaN               NaN                        NaN
# 5356                      NaN                No                        0.0
# 5357        Quality Assurance                No                        0.0
#
#      work_on_call_duty_charge_type  profile_age profile_gender  sueldo_verdad  \
# 0                              NaN           35      Varón Cis       300000.0
# 1                              NaN           31      Varón Cis       900000.0
# 2                              NaN           27      Varón Cis       120000.0
# 3                              NaN           21      Varón Cis       440000.0
# 4                              NaN           32      Varón Cis       140000.0
# ...                            ...          ...            ...            ...
# 5353                           NaN           40      Mujer Cis          311.7
# 5354                           NaN           33      Mujer Cis       150000.0
# 5355                           NaN           35          Mujer       230000.0
# 5356                          Neto           39      Varón cis       450989.0
# 5357                          Neto           33       Bigénero        60000.0
#
#                          cured_programming_languages
# 0                                           [python]
# 1     [css, html, java, javascript, sql, typescript]
# 2                          [javascript, php, python]
# 3                           [javascript, typescript]
# 4                            [css, html, javascript]
# ...                                              ...
# 5353                                              []
# 5354                                              []
# 5355                                     [html, sql]
# 5356                               [javascript, sql]
# 5357                                              []
#
# [5079 rows x 46 columns]

# %% [markdown]
# ### Conteo de frecuencias de los lenguajes de programación
#
# La columna que contiene información sobre los lenguajes de programación utilizados es `tools_programming_languages`. Sus valores son strings con los lenguajes seleccionados separados por comas.

# %%
df.tools_programming_languages[:10]
# Out:
# 0                                          Python
# 1    CSS, HTML, Java, Javascript, SQL, TypeScript
# 2                         Javascript, PHP, Python
# 3                          Javascript, TypeScript
# 4                           CSS, HTML, Javascript
# 5                                        Go, Java
# 6                                            Java
# 7               HTML, Javascript, SQL, TypeScript
# 8                                             SQL
# 9                                            Java
# Name: tools_programming_languages, dtype: object

# %% [markdown]
# Las siguientes celdas de código separan estos lenguajes de programación y cuentan la frecuencia con la que aparecen.
#
# No es necesario entender este código en profundidad, aunque sí es un buen ejercicio.

# %%
# Convert the comma-separated string of languages to a list of string.
# Remove 'ninguno de los anteriores' option, spaces and training commas.
def split_languages(languages_str):
  if not isinstance(languages_str, str):
    return []
  # Remove 'other' option
  languages_str = languages_str.lower()\
    .replace('ninguno de los anteriores', '')
  # Split string into list of items
  # Remove spaces and commas for each item
  return [lang.strip().replace(',', '')
          for lang in languages_str.split()]

# Create a new column with the list of languages
df.loc[:, 'cured_programming_languages'] = df.tools_programming_languages\
    .apply(split_languages)
if 'cured_programming_languages' not in relevant_columns:
    relevant_columns.append('cured_programming_languages') 

# Duplicate each row of df for each programming language
# mentioned in the response.
# We only include in df_lang the columns we are going to analyze later, so we
# don't duplicate innecesary information.
df_lang = df.cured_programming_languages\
    .apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame()\
    .join(df[relevant_columns])\
    .rename(columns={0: 'programming_language'})
# Horrible programming style! But a lot of data science code can be written with
# as concatenations of functions (pipelines), and there's no elegant way of
# doing that on Python.
df_lang[:5]
# Out:
#   programming_language work_dedication             work_contract_type  \
# 0               python       Full-Time      Staff (planta permanente)
# 1                  css       Full-Time  Remoto (empresa de otro país)
# 1                 html       Full-Time  Remoto (empresa de otro país)
# 1                 java       Full-Time  Remoto (empresa de otro país)
# 1           javascript       Full-Time  Remoto (empresa de otro país)
#
#                     tools_programming_languages  sueldo_verdad  \
# 0                                        Python       300000.0
# 1  CSS, HTML, Java, Javascript, SQL, TypeScript       900000.0
# 1  CSS, HTML, Java, Javascript, SQL, TypeScript       900000.0
# 1  CSS, HTML, Java, Javascript, SQL, TypeScript       900000.0
# 1  CSS, HTML, Java, Javascript, SQL, TypeScript       900000.0
#
#                       cured_programming_languages
# 0                                        [python]
# 1  [css, html, java, javascript, sql, typescript]
# 1  [css, html, java, javascript, sql, typescript]
# 1  [css, html, java, javascript, sql, typescript]
# 1  [css, html, java, javascript, sql, typescript]

# %% [markdown]
# En la columna `programming_language` se encuentra cada lenguaje por separado. Notar que si una respuesta contenía 3 lenguajes, como `"HTML, Javascript, Python"`, la fila ha sido replicada 3 veces. Por ello, hay tres filas con índice 1.

# %%
language_count = df_lang.programming_language.value_counts()\
    .reset_index()\
    .rename(columns={'index': 'language', 'programming_language': 'frequency'})
language_count[:10]
# Out:
#      language  frequency
# 0  javascript       2142
# 1         sql       2075
# 2        html       1541
# 3      python       1409
# 4         css       1051
# 5        java        967
# 6  typescript        948
# 7  bash/shell        859
# 8        .net        612
# 9         php        602

# %% [markdown]
# ## Filtrado de lenguajes relevantes
#
# El siguiente código permite seleccionar sólo las filas donde el valor de la columna `programming_language` se encuentre en la lista `interesting_languages`.

# %%
# Filter out languages that we want to exclude
# Complete here with your selected list.
interesting_languages = ["python"]
filtered_df_lang = df_lang[df_lang.programming_language.isin(interesting_languages)]
filtered_df_lang[:5]
# Out:
#    programming_language work_dedication  \
# 0                python       Full-Time
# 2                python       Full-Time
# 13               python       Full-Time
# 15               python       Full-Time
# 18               python       Part-Time
#
#                                    work_contract_type  \
# 0                           Staff (planta permanente)
# 2                           Staff (planta permanente)
# 13                      Remoto (empresa de otro país)
# 15                          Staff (planta permanente)
# 18  Tercerizado (trabajo a través de consultora o ...
#
#                           tools_programming_languages  sueldo_verdad  \
# 0                                              Python       300000.0
# 2                             Javascript, PHP, Python       120000.0
# 13                            Bash/Shell, Python, SQL       625000.0
# 15  Bash/Shell, HTML, Javascript, PHP, Python, Typ...       380000.0
# 18                       CSS, HTML, Java, Python, SQL        50000.0
#
#                           cured_programming_languages
# 0                                            [python]
# 2                           [javascript, php, python]
# 13                          [bash/shell, python, sql]
# 15  [bash/shell, html, javascript, php, python, ty...
# 18                     [css, html, java, python, sql]

# %% [markdown]
# # Ejercicio 2 - Densidades y varias variables
#
# Responder a la pregunta general: **¿Que herramientas (prácticas y teóricas) són útiles para explorar la base, descubrir patrones, asociaciones?**
#
# Para ello considere (igual al ejercicio Anterior):
# 1. Seleccionar las columnas relevantes para analizar.
# 2. Seleccionar las filas relevantes para analizar. Esto incluye la eliminación de valores extremos y erróneos, pero también puede enfocar el análisis en sub-poblaciones.

# %% [markdown]
# ## a) Densidad conjunta
#
# Que herramientas visuales y modelos puede utilizar para estudiar la distribución y comportamiento de sus datos?
#
# Elija tres variables numéricas y 2 variables categóricas. Visualice la base según varias de las variables elegidas. Puede describir de alguna forma el comportamiento de sus datos? Que herramientas utilizaría? Describa

# %% [markdown]
# ## b) Asociación
#
# * Necesitamos decidir si sacar o no la columna de salario bruto. Para hacer la encuesta más simple.
# ¿Existe una correlación entre el salario bruto y el neto? Que abordaje y medidas usaría

# %% [markdown]
# ## c) Densidad condicional
#
# Estudie la distribución del salario según el nivel de estudio.
#
# Separe la población según el nivel de estudio (elija dos subpoblaciones numerosas) y grafique de manera comparativa ambos histogramas de la variable `'salary_monthly_NETO'`
# ¿Considera que ambas variables son independientes?
# ¿Qué analizaría al respecto?
#
# Calcule medidas de centralización y dispersión para cada subpoblación

# %% [markdown]
# ## d) Densidad Conjunta condicional
#
# Elija dos variables numéricas y una categórica.
# Estudie la dispersión (scatterplot) de las dos variables discriminando en color por la variable categórica (ayuda: hue en seaborn)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dfaf0b2e-1d12-4005-a6ad-35bbea932474' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
